# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
# all packages are downloaded

# %%
#url = "https://www.hubertiming.com/home"
url = "https://www.hubertiming.com/results/2023Resolution"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, "lxml")

# %%
title = soup.title 
print(title)
print(title.txt)
# Out:
# <title>Race results for the 2023 to 2023 Resolution Relay!</title>
# None

# %%
links = soup.find_all('a', href=True)
print(links)
for link in links:
    print (link['href'])
# prints all links
# Out:
# [<a href="https://eastwind.run/" target="_blank">Eastwind Running and Endurance Club</a>, <a href="mailto:timing@hubertiming.com">timing@hubertiming.com</a>, <a href="https://www.hubertiming.com">Huber Timing Home</a>, <a class="btn btn-primary btn-lg" href="/results/2023Resolution3Person" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 3 Person Team</a>, <a class="btn btn-primary btn-lg" href="/results/2023Resolution2Person" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> 2 Person Team</a>, <a class="btn btn-primary btn-lg" href="/results/2023ResolutionIndividual" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Individual</a>, <a class="btn btn-primary btn-lg" href="/results/2023ResolutionRelayVirtual" role="button" style="margin: 0px 0px 5px 5px"><i aria-hidden="true" class="fa fa-user"></i> Half Virtual</a>, <a class="btn btn-primary btn-lg" href="/re
# ...

# %%
data = []
#allrows = soup.find_all("tr")
#print (allrows[:2]) # prints only 5 rows, else remove [:5] to view all or view row 0.
print (allrows[:10])
for row in allrows:
    #row_list = row.find_all("td")
    dataRow = []
    dataRow.append(cell.text)
    data.append (dataRow)
    titles = data[0]
    data = data[:1]
    print(titles)
    print (data [-2:])
   #print (row_list)
    for cell in row_list:
        print (cell.text)
# Out:
# [<tr colspan="2">
# <b>4 Person Team:</b>
# </tr>, <tr>
# <td>Finishers:</td>
# <td>15</td>
# </tr>, <tr>
# <td>Male:</td>
# <td>0</td>
# </tr>, <tr>
# <td>Female:</td>
# <td>4</td>
# </tr>, <tr>
# <td>Non-Binary:</td>
# <td>11</td>
# </tr>, <tr class="header">
# <th>Place</th>
# <th>Bib</th>
# <th>Name</th>
# <th>Gender</th>
# <th>Chip Time</th>
# <th>Gun Time</th>
# </tr>, <tr data-bib="405">
# <td>1</td>
# <td>405</td>
# <td>
#
#                     TEAM FLASH
#
#                 </td>
# <td>I</td>
# <td>1:30:54</td>
# <td>1:30:54</td>
# </tr>, <tr data-bib="402">
# <td>2</td>
# <td>402</td>
# <td>
#
#                     STAR IS BACK!
#
#                 </td>
# <td>I</td>
# <td>1:39:46</td>
# <td>1:39:46</td>
# </tr>, <tr data-bib="401">
# <td>3</td>
# <td>401</td>
# <td>
#
#                     THERAPEUTIC ASSOCIATES
#
#                 </td>
# <td>I</td>
# <td>1:48:14</td>
# <td>1:48:14</td>
# </tr>, <tr data-bib="410">
# <td>4</td>
# <td>410</td>
# <td>
#
# ...

# %%
df = pd.DataFrame(data)
print(data)
print(df.head())
print(df.tail())
# Out:
# [['3:04:22']]
#          0
# 0  3:04:22
#          0
# 0  3:04:22

# %%
header_list = []
#col_headers = soup.find_all('th')
for col in col_headers:
    header_list.append(col.text)
    print (header_list)
#col_header
# Out:
# ['Place']
# ['Place', 'Bib']
# ['Place', 'Bib', 'Name']
# ['Place', 'Bib', 'Name', 'Gender']
# ['Place', 'Bib', 'Name', 'Gender', 'Chip Time']
# ['Place', 'Bib', 'Name', 'Gender', 'Chip Time', 'Gun Time']

# %%
df.columns = header_list
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19528\2211643514.py in <module>
# ----> 1 df.columns = header_list
#       2 print(df.columns())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
# ...

# %%
list1=["Python","Java","c","C","C++"]
print(min(list1))
# Out:
# C

# %%
 i = 1 
while True: 
    if i%5 == 0: 
        break
         i += 1
        print(i)
